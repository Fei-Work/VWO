# %%
import pandas as pd
import os

# %%
file_name = '/media/liu/KINGSTON/Complex_Urban_LiDAR_Data_Set/urban39-pankyo/sensor_data/stereo_stamp.csv'
time_stamp = pd.read_csv(file_name, header=None)[0].tolist()
time_stamp
# Out:
# [1559195795611174799,
#  1559195795711012276,
#  1559195795811099519,
#  1559195795911144722,
#  1559195796011210378,
#  1559195796111041200,
#  1559195796211144998,
#  1559195796310968835,
#  1559195796411187596,
#  1559195796511106368,
#  1559195796611332081,
#  1559195796711159508,
#  1559195796811169287,
#  1559195796911209141,
#  1559195797011308025,
#  1559195797111988702,
#  1559195797211384270,
#  1559195797311262521,
#  1559195797411264692,
#  1559195797511211996,
#  1559195797611414088,
#  1559195797711114422,
#  1559195797811195457,
#  1559195797911205069,
#  1559195798011249241,
#  1559195798111231314,
#  1559195798211699251,
#  1559195798311256655,
#  1559195798411471196,
#  1559195798511366734,
#  1559195798611407345,
#  1559195798711281741,
#  1559195798811168192,
#  1559195798911216890,
#  1559195799011248841,
#  1559195799111280302,
#  1559195799211363455,
#  1559195799311280450,
#  1559195799411391686,
#  1559195799511168446,
#  1559195799611284193,
# ...

# %%
leftdir = '/media/liu/KINGSTON/Complex_Urban_LiDAR_Data_Set/urban39-pankyo/image/stereo_left'
rightdir = '/media/liu/KINGSTON/Complex_Urban_LiDAR_Data_Set/urban39-pankyo/image/stereo_right'

# %%
left = os.listdir(leftdir)
right = os.listdir(rightdir)
newleft = list(map(int,[item.replace('.png', '') for item in left]))
newright = list(map(int,[item.replace('.png', '') for item in right]))

# %%
def check(true_time, check_time):
    for item in true_time:
        if item not in check_time:
            print(item)
            # true_time.remove(item)

check(newleft, newright)
# Out:
# 1559195795611174799
# 1559196800424766281
# 1559196800524652056
# 1559196800624600447
# 1559197401633230390
# 1559197401733304781
# 1559197552235214635
# 1559197552335182420
# 1559197552435252199

# %%
len(newleft)
# Out:
# 18657

# %%
len(time_stamp)
# Out:
# 18648

# %%
len(newright)
# Out:
# 18660

# %%
df = pd.DataFrame(time_stamp)
df.to_csv('/media/liu/KINGSTON/Complex_Urban_LiDAR_Data_Set/urban39-pankyo/sensor_data/stereo_stamp_new.csv',index=None, header=None)
