# %%
import pandas as pd
import os

# %%
# file_name = '/media/liu/KINGSTON/Complex_Urban_LiDAR_Data_Set/urban33-yeouido/sensor_data/stereo_stamp_new.csv'
file_name = '/media/liu/KINGSTON/Complex_Urban_LiDAR_Data_Set/urban26-dongtan/sensor_data/stereo_stamp.csv'
time_stamp = pd.read_csv(file_name, header=None)[0].tolist()
time_stamp
# Out:
# [1544580706215305091,
#  1544580706315326700,
#  1544580706415456050,
#  1544580706515176655,
#  1544580706615143198,
#  1544580706715046970,
#  1544580706817717134,
#  1544580706915365747,
#  1544580707015209030,
#  1544580707115371480,
#  1544580707215321005,
#  1544580707315434306,
#  1544580707415318990,
#  1544580707515461841,
#  1544580707615244529,
#  1544580707715456956,
#  1544580707815606097,
#  1544580707915475634,
#  1544580708015203694,
#  1544580708115189898,
#  1544580708215338225,
#  1544580708315286377,
#  1544580708415117654,
#  1544580708515164642,
#  1544580708616249695,
#  1544580708715509001,
#  1544580708815655612,
#  1544580708915620787,
#  1544580709015690112,
#  1544580709115528328,
#  1544580709215513521,
#  1544580709315697049,
#  1544580709415674617,
#  1544580709516047773,
#  1544580709615562684,
#  1544580709715403085,
#  1544580709815299653,
#  1544580709915390343,
#  1544580710015337532,
#  1544580710115535028,
#  1544580710215466149,
# ...

# %%
# leftdir = '/media/liu/KINGSTON/Complex_Urban_LiDAR_Data_Set/urban33-yeouido/image/stereo_left'
# rightdir = '/media/liu/KINGSTON/Complex_Urban_LiDAR_Data_Set/urban33-yeouido/image/stereo_right'
leftdir = '/media/liu/KINGSTON/Complex_Urban_LiDAR_Data_Set/urban26-dongtan/image/stereo_left'
rightdir = '/media/liu/KINGSTON/Complex_Urban_LiDAR_Data_Set/urban26-dongtan/image/stereo_right'

# %%
left = os.listdir(leftdir)
right = os.listdir(rightdir)
newleft = list(map(int,[item.replace('.png', '') for item in left]))
newright = list(map(int,[item.replace('.png', '') for item in right]))

# %%
def check(true_time, check_time):
    for item in true_time:
        if item not in check_time:
            print(item)
            # true_time.remove(item)

check(time_stamp,newright)

# %%
len(time_stamp)
# Out:
# 5837

# %%
len(newright)
# Out:
# 5837

# %%
len(newleft)
# Out:
# 5837

# %%
df = pd.DataFrame(time_stamp)
df.to_csv(file_name,index=None, header=None)
